# %% [markdown]
# # 11-class Strong Attention Comparison
#
# This notebook trains and compares three 11-class AMR models on the same RadioML2016.10a split:
#
# 1. Baseline MCLDNN with 2?LSTM-128
# 2. Normal MCLDNN attention
# 3. Strong higher-capacity MCLDNN attention
#
# The new strong attention model keeps the same 3-branch CNN front-end, then adds:
#
# - 100 ? 128 sequence projection
# - sinusoidal positional encoding
# - two residual self-attention blocks
# - gated temporal pooling plus mean/max statistics
# - larger regularized classifier head
#
# Goal: test whether a fairer, higher-capacity attention model can close or exceed the LSTM advantage, especially at high SNR.

# %%
# CELL 1: Setup repo and paths
import os
import sys
import shutil
import subprocess
from pathlib import Path
from datetime import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, display, FileLink, HTML

os.environ['KERAS_BACKEND'] = 'tensorflow'

REPO_URL = 'https://github.com/akshlabh/amr-5-class.git'
WORK_DIR = Path('/kaggle/working/amr-5-class')

DATASET_CANDIDATES = [
    Path('/kaggle/input/datasets/gustavopolicarpo/rml201610a-dict/RML2016.10a_dict.dat'),
    Path('/kaggle/input/rml201610a-dict/RML2016.10a_dict.dat'),
    Path('/kaggle/input/radioml2016-10a/RML2016.10a_dict.pkl'),
    Path('/kaggle/input/radioml2016-10a/RML2016.10a_dict.dat'),
    Path('data/RML2016.10a_dict.pkl'),
    Path('data/RML2016.10a_dict.dat'),
]

def find_attached_repo():
    input_root = Path('/kaggle/input')
    if not input_root.exists():
        return None
    for root in input_root.glob('**'):
        if (root / 'src' / 'train.py').exists() and (root / 'configs').exists():
            return root
    return None

if (Path.cwd() / 'src' / 'train.py').exists():
    WORK_DIR = Path.cwd()
    print('Using current repo:', WORK_DIR)
elif (WORK_DIR / 'src' / 'train.py').exists():
    print('Using existing repo:', WORK_DIR)
    try:
        subprocess.run(['git', '-C', str(WORK_DIR), 'pull'], check=False)
    except Exception as e:
        print('Git pull skipped:', e)
else:
    attached = find_attached_repo()
    if attached is not None:
        print('Copying attached repo from:', attached)
        if WORK_DIR.exists():
            shutil.rmtree(WORK_DIR)
        shutil.copytree(attached, WORK_DIR)
    else:
        print('Cloning repo from GitHub...')
        subprocess.run(['git', 'clone', REPO_URL, str(WORK_DIR)], check=True)

os.chdir(WORK_DIR)
if str(WORK_DIR) not in sys.path:
    sys.path.insert(0, str(WORK_DIR))

DATASET = next((p for p in DATASET_CANDIDATES if p.exists()), None)
assert DATASET is not None, 'Dataset not found. Set DATASET manually in this cell.'

BASELINE_DIR = Path('experiments/11class_baseline')
NORMAL_ATT_DIR = Path('experiments/11class_attention')
STRONG_ATT_DIR = Path('experiments/11class_attention_strong')
COMPARE_DIR = Path('experiments/11class_attention_strong_comparison')
FIG_DIR = COMPARE_DIR / 'figures'
RES_DIR = COMPARE_DIR / 'results'
FIG_DIR.mkdir(parents=True, exist_ok=True)
RES_DIR.mkdir(parents=True, exist_ok=True)

print('Working dir:', Path.cwd())
print('Dataset    :', DATASET)
print('Dataset OK :', DATASET.exists())
# Out:
# Using current repo: /kaggle/working/amr-5-class
# Working dir: /kaggle/working/amr-5-class
# Dataset    : /kaggle/input/datasets/gustavopolicarpo/rml201610a-dict/RML2016.10a_dict.dat
# Dataset OK : True

# %%
# CELL 2: Verify required files and model parameter counts
import keras
keras.mixed_precision.set_global_policy('float32')

required = [
    'src/train.py',
    'src/dataset.py',
    'src/models/mcldnn.py',
    'src/models/mcldnn_attention.py',
    'src/models/mcldnn_attention_strong.py',
    'configs/exp_11class_baseline.yaml',
    'configs/exp_11class_attention.yaml',
    'configs/exp_11class_attention_strong.yaml',
]
for f in required:
    print(('OK      ' if Path(f).exists() else 'MISSING ') + f)
    assert Path(f).exists(), f'Missing required file: {f}'

from src.models.mcldnn import MCLDNN
from src.models.mcldnn_attention import build_mcldnn_attention
from src.models.mcldnn_attention_strong import build_mcldnn_attention_strong

models_for_count = {
    'Baseline MCLDNN LSTM': MCLDNN(classes=11),
    'Normal attention': build_mcldnn_attention(classes=11),
    'Strong attention': build_mcldnn_attention_strong(classes=11),
}

print('\nParameter counts')
print('-' * 50)

for name, model in models_for_count.items():
    print(f'{name:<28} {model.count_params():>12,}')
    del model

keras.backend.clear_session()
# Out:
# OK      src/train.py
# OK      src/dataset.py
# OK      src/models/mcldnn.py
# OK      src/models/mcldnn_attention.py
# OK      src/models/mcldnn_attention_strong.py
# OK      configs/exp_11class_baseline.yaml
# OK      configs/exp_11class_attention.yaml
# OK      configs/exp_11class_attention_strong.yaml
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1784043786.038713      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Parameter counts
# --------------------------------------------------
# Baseline MCLDNN LSTM              405,175
# Normal attention                  245,115
# Strong attention                  483,800

# %%
# CELL 3: Train missing models
# Each model is trained only if its best checkpoint is missing.

def run_stream(cmd):
    print('Running:', ' '.join(map(str, cmd)))
    process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1)
    for line in process.stdout:
        print(line, end='', flush=True)
    rc = process.wait()
    if rc != 0:
        raise subprocess.CalledProcessError(rc, process.args)

def checkpoint_ready(exp_dir):
    return (Path(exp_dir) / 'checkpoints/best_model.weights.h5').exists()

jobs = [
    ('11class_baseline_lstm', BASELINE_DIR, 'configs/exp_11class_baseline.yaml'),
    ('11class_normal_attention', NORMAL_ATT_DIR, 'configs/exp_11class_attention.yaml'),
    ('11class_strong_attention', STRONG_ATT_DIR, 'configs/exp_11class_attention_strong.yaml'),
]

for name, exp_dir, cfg in jobs:
    if checkpoint_ready(exp_dir):
        print(f'{name}: checkpoint found, skipping training -> {exp_dir}/checkpoints/best_model.weights.h5')
    else:
        print(f'{name}: checkpoint missing, training now...')
        run_stream([sys.executable, '-u', 'src/train.py', '--config', cfg, '--datasetpath', str(DATASET)])
        assert checkpoint_ready(exp_dir), f'Training finished but checkpoint missing: {exp_dir}'
# Out:
# 11class_baseline_lstm: checkpoint missing, training now...
# Running: /usr/bin/python3 -u src/train.py --config configs/exp_11class_baseline.yaml --datasetpath /kaggle/input/datasets/gustavopolicarpo/rml201610a-dict/RML2016.10a_dict.dat
# [seed] All seeds fixed to 2016  (Python, NumPy, TensorFlow 2.20.0)
#
# ============================================================
#   Experiment : 11class_baseline
#   Model      : mcldnn
#   Branch     : full
#   Dropout    : 0.5
#   L2 Dense   : 0.001   L2 LSTM : 0.0001
#   SNR Weighted: False
#   Initial LR : 0.001
#   SNR Range  : None
#   Shuffle Split: False
#   Classes    : ['8PSK', 'AM-DSB', 'AM-SSB', 'BPSK', 'CPFSK', 'GFSK', 'PAM4', 'QAM16', 'QAM64', 'QPSK', 'WBFM']
#   n_classes  : 11
#   Checkpoint : experiments/11class_baseline/checkpoints/best_model.weights.h5
# ============================================================
#
# [dataset] Loading 11 classes: ['8PSK', 'AM-DSB', 'AM-SSB', 'BPSK', 'CPFSK', 'GFSK', 'PAM4', 'QAM16', 'QAM64', 'QPSK', 'WBFM']
# [dataset] SNR range: -20 dB to 18 dB  (20 levels)
# [dataset] After normalization — train RMS: 1.0000  (should be ≈1.0)
# [dataset] Split: 132000 train | 44000 val | 44000 test samples
# [train] Input shapes: IQ=(132000, 2, 128, 1)  I=(132000, 128, 1)  Q=(132000, 128, 1)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1784043805.411584     176 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15247 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "MCLDNN"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input2 (InputLayer) │ (None, 128, 1)    │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input3 (InputLayer) │ (None, 128, 1)    │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_2 (Conv1D)    │ (None, 128, 50)   │        450 │ input2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_3 (Conv1D)    │ (None, 128, 50)   │        450 │ input3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_i (Reshape) │ (None, 1, 128,    │          0 │ conv1_2[0][0]     │
# │                     │ 50)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_q (Reshape) │ (None, 1, 128,    │          0 │ conv1_3[0][0]     │
# │                     │ 50)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input1 (InputLayer) │ (None, 2, 128, 1) │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 2, 128,    │          0 │ reshape_i[0][0],  │
# │ (Concatenate)       │ 50)               │            │ reshape_q[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_1 (Conv2D)    │ (None, 2, 128,    │        850 │ input1[0][0]      │
# │                     │ 50)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2 (Conv2D)      │ (None, 2, 128,    │     20,050 │ concatenate[0][0] │
# │                     │ 50)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 2, 128,    │          0 │ conv1_1[0][0],    │
# │ (Concatenate)       │ 100)              │            │ conv2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4 (Conv2D)      │ (None, 1, 124,    │    100,100 │ concatenate_1[0]… │
# │                     │ 100)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_lstm        │ (None, 124, 100)  │          0 │ conv4[0][0]       │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 124, 128)  │    117,248 │ reshape_lstm[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 128)       │    131,584 │ lstm_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc1 (Dense)         │ (None, 128)       │     16,512 │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drop1 (Dropout)     │ (None, 128)       │          0 │ fc1[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc2 (Dense)         │ (None, 128)       │     16,512 │ drop1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drop2 (Dropout)     │ (None, 128)       │          0 │ fc2[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ softmax (Dense)     │ (None, 11)        │      1,419 │ drop2[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 405,175 (1.55 MB)
#  Trainable params: 405,175 (1.55 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10000
#
# Epoch 1: val_accuracy improved from None to 0.39098, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 1: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 30s - 90ms/step - accuracy: 0.3332 - loss: 1.9649 - val_accuracy: 0.3910 - val_loss: 1.6805 - learning_rate: 0.0010
# Epoch 2/10000
#
# Epoch 2: val_accuracy improved from 0.39098 to 0.44800, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 2: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.4317 - loss: 1.6111 - val_accuracy: 0.4480 - val_loss: 1.5474 - learning_rate: 0.0010
# Epoch 3/10000
#
# Epoch 3: val_accuracy improved from 0.44800 to 0.48039, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 3: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.4707 - loss: 1.4771 - val_accuracy: 0.4804 - val_loss: 1.4290 - learning_rate: 0.0010
# Epoch 4/10000
#
# Epoch 4: val_accuracy improved from 0.48039 to 0.51045, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 4: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.4887 - loss: 1.4130 - val_accuracy: 0.5105 - val_loss: 1.3622 - learning_rate: 0.0010
# Epoch 5/10000
#
# Epoch 5: val_accuracy improved from 0.51045 to 0.53159, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 5: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.5141 - loss: 1.3705 - val_accuracy: 0.5316 - val_loss: 1.3330 - learning_rate: 0.0010
# Epoch 6/10000
#
# Epoch 6: val_accuracy improved from 0.53159 to 0.53782, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 6: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.5323 - loss: 1.3239 - val_accuracy: 0.5378 - val_loss: 1.3058 - learning_rate: 0.0010
# Epoch 7/10000
#
# Epoch 7: val_accuracy improved from 0.53782 to 0.54302, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 7: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.5368 - loss: 1.3065 - val_accuracy: 0.5430 - val_loss: 1.2858 - learning_rate: 0.0010
# Epoch 8/10000
#
# Epoch 8: val_accuracy improved from 0.54302 to 0.54486, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 8: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.5409 - loss: 1.2941 - val_accuracy: 0.5449 - val_loss: 1.2801 - learning_rate: 0.0010
# Epoch 9/10000
#
# Epoch 9: val_accuracy improved from 0.54486 to 0.55309, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 9: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.5449 - loss: 1.2811 - val_accuracy: 0.5531 - val_loss: 1.2556 - learning_rate: 0.0010
# Epoch 10/10000
#
# Epoch 10: val_accuracy did not improve from 0.55309
# 330/330 - 21s - 64ms/step - accuracy: 0.5484 - loss: 1.2692 - val_accuracy: 0.5530 - val_loss: 1.2540 - learning_rate: 0.0010
# Epoch 11/10000
#
# Epoch 11: val_accuracy did not improve from 0.55309
# 330/330 - 21s - 64ms/step - accuracy: 0.5491 - loss: 1.2725 - val_accuracy: 0.5469 - val_loss: 1.2927 - learning_rate: 0.0010
# Epoch 12/10000
#
# Epoch 12: val_accuracy did not improve from 0.55309
# 330/330 - 21s - 64ms/step - accuracy: 0.5520 - loss: 1.2606 - val_accuracy: 0.5476 - val_loss: 1.2866 - learning_rate: 0.0010
# Epoch 13/10000
#
# Epoch 13: val_accuracy improved from 0.55309 to 0.55541, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 13: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.5535 - loss: 1.2533 - val_accuracy: 0.5554 - val_loss: 1.2527 - learning_rate: 0.0010
# Epoch 14/10000
#
# Epoch 14: val_accuracy did not improve from 0.55541
# 330/330 - 21s - 64ms/step - accuracy: 0.5567 - loss: 1.2492 - val_accuracy: 0.5502 - val_loss: 1.2623 - learning_rate: 0.0010
# Epoch 15/10000
#
# Epoch 15: val_accuracy improved from 0.55541 to 0.55768, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 15: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.5600 - loss: 1.2385 - val_accuracy: 0.5577 - val_loss: 1.2332 - learning_rate: 0.0010
# Epoch 16/10000
#
# Epoch 16: val_accuracy did not improve from 0.55768
# 330/330 - 21s - 63ms/step - accuracy: 0.5618 - loss: 1.2344 - val_accuracy: 0.5539 - val_loss: 1.2515 - learning_rate: 0.0010
# Epoch 17/10000
#
# Epoch 17: val_accuracy did not improve from 0.55768
# 330/330 - 21s - 63ms/step - accuracy: 0.5625 - loss: 1.2320 - val_accuracy: 0.5502 - val_loss: 1.2512 - learning_rate: 0.0010
# Epoch 18/10000
#
# Epoch 18: val_accuracy improved from 0.55768 to 0.56423, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 18: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.5657 - loss: 1.2284 - val_accuracy: 0.5642 - val_loss: 1.2146 - learning_rate: 0.0010
# Epoch 19/10000
#
# Epoch 19: val_accuracy did not improve from 0.56423
# 330/330 - 21s - 64ms/step - accuracy: 0.5683 - loss: 1.2178 - val_accuracy: 0.5496 - val_loss: 1.2404 - learning_rate: 0.0010
# Epoch 20/10000
#
# Epoch 20: val_accuracy improved from 0.56423 to 0.56914, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 20: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.5682 - loss: 1.2181 - val_accuracy: 0.5691 - val_loss: 1.2024 - learning_rate: 0.0010
# Epoch 21/10000
#
# Epoch 21: val_accuracy did not improve from 0.56914
# 330/330 - 21s - 64ms/step - accuracy: 0.5730 - loss: 1.2028 - val_accuracy: 0.5621 - val_loss: 1.2161 - learning_rate: 0.0010
# Epoch 22/10000
#
# Epoch 22: val_accuracy did not improve from 0.56914
# 330/330 - 21s - 64ms/step - accuracy: 0.5712 - loss: 1.2098 - val_accuracy: 0.5624 - val_loss: 1.2263 - learning_rate: 0.0010
# Epoch 23/10000
#
# Epoch 23: val_accuracy did not improve from 0.56914
# 330/330 - 21s - 64ms/step - accuracy: 0.5734 - loss: 1.2034 - val_accuracy: 0.5678 - val_loss: 1.2041 - learning_rate: 0.0010
# Epoch 24/10000
#
# Epoch 24: val_accuracy improved from 0.56914 to 0.57343, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 24: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.5748 - loss: 1.1970 - val_accuracy: 0.5734 - val_loss: 1.1825 - learning_rate: 0.0010
# Epoch 25/10000
#
# Epoch 25: val_accuracy improved from 0.57343 to 0.57498, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 25: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.5784 - loss: 1.1879 - val_accuracy: 0.5750 - val_loss: 1.1859 - learning_rate: 0.0010
# Epoch 26/10000
#
# Epoch 26: val_accuracy did not improve from 0.57498
# 330/330 - 21s - 64ms/step - accuracy: 0.5800 - loss: 1.1772 - val_accuracy: 0.5741 - val_loss: 1.1895 - learning_rate: 0.0010
# Epoch 27/10000
#
# Epoch 27: val_accuracy improved from 0.57498 to 0.57580, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 27: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.5814 - loss: 1.1731 - val_accuracy: 0.5758 - val_loss: 1.1708 - learning_rate: 0.0010
# Epoch 28/10000
#
# Epoch 28: val_accuracy improved from 0.57580 to 0.57800, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 28: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.5852 - loss: 1.1614 - val_accuracy: 0.5780 - val_loss: 1.1833 - learning_rate: 0.0010
# Epoch 29/10000
#
# Epoch 29: val_accuracy improved from 0.57800 to 0.57973, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 29: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.5866 - loss: 1.1565 - val_accuracy: 0.5797 - val_loss: 1.1751 - learning_rate: 0.0010
# Epoch 30/10000
#
# Epoch 30: val_accuracy improved from 0.57973 to 0.58473, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 30: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.5866 - loss: 1.1522 - val_accuracy: 0.5847 - val_loss: 1.1632 - learning_rate: 0.0010
# Epoch 31/10000
#
# Epoch 31: val_accuracy did not improve from 0.58473
# 330/330 - 21s - 65ms/step - accuracy: 0.5889 - loss: 1.1444 - val_accuracy: 0.5800 - val_loss: 1.1685 - learning_rate: 0.0010
# Epoch 32/10000
#
# Epoch 32: val_accuracy did not improve from 0.58473
# 330/330 - 21s - 64ms/step - accuracy: 0.5888 - loss: 1.1463 - val_accuracy: 0.5773 - val_loss: 1.2086 - learning_rate: 0.0010
# Epoch 33/10000
#
# Epoch 33: val_accuracy improved from 0.58473 to 0.58602, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 33: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.5922 - loss: 1.1354 - val_accuracy: 0.5860 - val_loss: 1.1528 - learning_rate: 0.0010
# Epoch 34/10000
#
# Epoch 34: val_accuracy did not improve from 0.58602
# 330/330 - 21s - 65ms/step - accuracy: 0.5895 - loss: 1.1413 - val_accuracy: 0.5810 - val_loss: 1.1589 - learning_rate: 0.0010
# Epoch 35/10000
#
# Epoch 35: val_accuracy did not improve from 0.58602
# 330/330 - 21s - 64ms/step - accuracy: 0.5928 - loss: 1.1328 - val_accuracy: 0.5691 - val_loss: 1.2091 - learning_rate: 0.0010
# Epoch 36/10000
#
# Epoch 36: val_accuracy improved from 0.58602 to 0.58811, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 36: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 22s - 65ms/step - accuracy: 0.5952 - loss: 1.1233 - val_accuracy: 0.5881 - val_loss: 1.1441 - learning_rate: 0.0010
# Epoch 37/10000
#
# Epoch 37: val_accuracy did not improve from 0.58811
# 330/330 - 21s - 65ms/step - accuracy: 0.5969 - loss: 1.1243 - val_accuracy: 0.5751 - val_loss: 1.1798 - learning_rate: 0.0010
# Epoch 38/10000
#
# Epoch 38: val_accuracy did not improve from 0.58811
# 330/330 - 21s - 65ms/step - accuracy: 0.5959 - loss: 1.1202 - val_accuracy: 0.5745 - val_loss: 1.1750 - learning_rate: 0.0010
# Epoch 39/10000
#
# Epoch 39: val_accuracy did not improve from 0.58811
# 330/330 - 21s - 65ms/step - accuracy: 0.5981 - loss: 1.1094 - val_accuracy: 0.5858 - val_loss: 1.1375 - learning_rate: 0.0010
# Epoch 40/10000
#
# Epoch 40: val_accuracy did not improve from 0.58811
# 330/330 - 21s - 64ms/step - accuracy: 0.5982 - loss: 1.1168 - val_accuracy: 0.5854 - val_loss: 1.1619 - learning_rate: 0.0010
# Epoch 41/10000
#
# Epoch 41: val_accuracy improved from 0.58811 to 0.59159, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 41: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.6001 - loss: 1.1096 - val_accuracy: 0.5916 - val_loss: 1.1465 - learning_rate: 0.0010
# Epoch 42/10000
#
# Epoch 42: val_accuracy did not improve from 0.59159
# 330/330 - 21s - 65ms/step - accuracy: 0.6002 - loss: 1.1043 - val_accuracy: 0.5797 - val_loss: 1.1855 - learning_rate: 0.0010
# Epoch 43/10000
#
# Epoch 43: val_accuracy did not improve from 0.59159
# 330/330 - 21s - 65ms/step - accuracy: 0.5997 - loss: 1.1093 - val_accuracy: 0.5912 - val_loss: 1.1602 - learning_rate: 0.0010
# Epoch 44/10000
#
# Epoch 44: val_accuracy did not improve from 0.59159
# 330/330 - 21s - 65ms/step - accuracy: 0.6015 - loss: 1.1057 - val_accuracy: 0.5866 - val_loss: 1.1469 - learning_rate: 0.0010
# Epoch 45/10000
#
# Epoch 45: val_accuracy did not improve from 0.59159
# 330/330 - 21s - 65ms/step - accuracy: 0.6012 - loss: 1.1045 - val_accuracy: 0.5838 - val_loss: 1.1723 - learning_rate: 0.0010
# Epoch 46/10000
#
# Epoch 46: val_accuracy improved from 0.59159 to 0.59514, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 46: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.6026 - loss: 1.0977 - val_accuracy: 0.5951 - val_loss: 1.1456 - learning_rate: 0.0010
# Epoch 47/10000
#
# Epoch 47: val_accuracy did not improve from 0.59514
# 330/330 - 21s - 64ms/step - accuracy: 0.6050 - loss: 1.0952 - val_accuracy: 0.5856 - val_loss: 1.1746 - learning_rate: 0.0010
# Epoch 48/10000
#
# Epoch 48: val_accuracy did not improve from 0.59514
# 330/330 - 21s - 64ms/step - accuracy: 0.6039 - loss: 1.1022 - val_accuracy: 0.5845 - val_loss: 1.1892 - learning_rate: 0.0010
# Epoch 49/10000
#
# Epoch 49: val_accuracy did not improve from 0.59514
# 330/330 - 21s - 65ms/step - accuracy: 0.6051 - loss: 1.0953 - val_accuracy: 0.5884 - val_loss: 1.1325 - learning_rate: 0.0010
# Epoch 50/10000
#
# Epoch 50: val_accuracy did not improve from 0.59514
# 330/330 - 21s - 64ms/step - accuracy: 0.6083 - loss: 1.0848 - val_accuracy: 0.5896 - val_loss: 1.1602 - learning_rate: 0.0010
# Epoch 51/10000
#
# Epoch 51: val_accuracy did not improve from 0.59514
# 330/330 - 21s - 65ms/step - accuracy: 0.6069 - loss: 1.0913 - val_accuracy: 0.5908 - val_loss: 1.1422 - learning_rate: 0.0010
# Epoch 52/10000
#
# Epoch 52: val_accuracy did not improve from 0.59514
# 330/330 - 21s - 64ms/step - accuracy: 0.6076 - loss: 1.0908 - val_accuracy: 0.5945 - val_loss: 1.1530 - learning_rate: 0.0010
# Epoch 53/10000
#
# Epoch 53: val_accuracy did not improve from 0.59514
# 330/330 - 21s - 65ms/step - accuracy: 0.6094 - loss: 1.0814 - val_accuracy: 0.5872 - val_loss: 1.1811 - learning_rate: 0.0010
# Epoch 54/10000
#
# Epoch 54: val_accuracy did not improve from 0.59514
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 330/330 - 21s - 64ms/step - accuracy: 0.6097 - loss: 1.0780 - val_accuracy: 0.5844 - val_loss: 1.2256 - learning_rate: 0.0010
# Epoch 55/10000
#
# Epoch 55: val_accuracy improved from 0.59514 to 0.60416, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 55: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.6216 - loss: 1.0361 - val_accuracy: 0.6042 - val_loss: 1.1009 - learning_rate: 5.0000e-04
# Epoch 56/10000
#
# Epoch 56: val_accuracy improved from 0.60416 to 0.60614, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 56: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.6259 - loss: 1.0196 - val_accuracy: 0.6061 - val_loss: 1.1235 - learning_rate: 5.0000e-04
# Epoch 57/10000
#
# Epoch 57: val_accuracy did not improve from 0.60614
# 330/330 - 21s - 65ms/step - accuracy: 0.6281 - loss: 1.0106 - val_accuracy: 0.6058 - val_loss: 1.1153 - learning_rate: 5.0000e-04
# Epoch 58/10000
#
# Epoch 58: val_accuracy did not improve from 0.60614
# 330/330 - 21s - 64ms/step - accuracy: 0.6302 - loss: 1.0049 - val_accuracy: 0.6046 - val_loss: 1.1075 - learning_rate: 5.0000e-04
# Epoch 59/10000
#
# Epoch 59: val_accuracy improved from 0.60614 to 0.60759, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 59: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.6304 - loss: 0.9981 - val_accuracy: 0.6076 - val_loss: 1.1002 - learning_rate: 5.0000e-04
# Epoch 60/10000
#
# Epoch 60: val_accuracy did not improve from 0.60759
# 330/330 - 21s - 64ms/step - accuracy: 0.6322 - loss: 0.9953 - val_accuracy: 0.6061 - val_loss: 1.1144 - learning_rate: 5.0000e-04
# Epoch 61/10000
#
# Epoch 61: val_accuracy did not improve from 0.60759
# 330/330 - 21s - 65ms/step - accuracy: 0.6360 - loss: 0.9883 - val_accuracy: 0.6045 - val_loss: 1.1084 - learning_rate: 5.0000e-04
# Epoch 62/10000
#
# Epoch 62: val_accuracy improved from 0.60759 to 0.60820, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 62: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.6334 - loss: 0.9916 - val_accuracy: 0.6082 - val_loss: 1.1131 - learning_rate: 5.0000e-04
# Epoch 63/10000
#
# Epoch 63: val_accuracy improved from 0.60820 to 0.61132, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 63: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.6354 - loss: 0.9887 - val_accuracy: 0.6113 - val_loss: 1.0994 - learning_rate: 5.0000e-04
# Epoch 64/10000
#
# Epoch 64: val_accuracy did not improve from 0.61132
# 330/330 - 21s - 64ms/step - accuracy: 0.6362 - loss: 0.9867 - val_accuracy: 0.6096 - val_loss: 1.0982 - learning_rate: 5.0000e-04
# Epoch 65/10000
#
# Epoch 65: val_accuracy did not improve from 0.61132
# 330/330 - 21s - 65ms/step - accuracy: 0.6368 - loss: 0.9876 - val_accuracy: 0.6085 - val_loss: 1.1162 - learning_rate: 5.0000e-04
# Epoch 66/10000
#
# Epoch 66: val_accuracy did not improve from 0.61132
# 330/330 - 21s - 64ms/step - accuracy: 0.6359 - loss: 0.9912 - val_accuracy: 0.6088 - val_loss: 1.1011 - learning_rate: 5.0000e-04
# Epoch 67/10000
#
# Epoch 67: val_accuracy did not improve from 0.61132
# 330/330 - 21s - 65ms/step - accuracy: 0.6377 - loss: 0.9808 - val_accuracy: 0.6055 - val_loss: 1.1048 - learning_rate: 5.0000e-04
# Epoch 68/10000
#
# Epoch 68: val_accuracy did not improve from 0.61132
# 330/330 - 21s - 64ms/step - accuracy: 0.6394 - loss: 0.9793 - val_accuracy: 0.6056 - val_loss: 1.1036 - learning_rate: 5.0000e-04
# Epoch 69/10000
#
# Epoch 69: val_accuracy did not improve from 0.61132
# 330/330 - 21s - 64ms/step - accuracy: 0.6399 - loss: 0.9776 - val_accuracy: 0.6105 - val_loss: 1.0960 - learning_rate: 5.0000e-04
# Epoch 70/10000
#
# Epoch 70: val_accuracy did not improve from 0.61132
# 330/330 - 21s - 64ms/step - accuracy: 0.6405 - loss: 0.9756 - val_accuracy: 0.6080 - val_loss: 1.1131 - learning_rate: 5.0000e-04
# Epoch 71/10000
#
# Epoch 71: val_accuracy did not improve from 0.61132
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 330/330 - 21s - 64ms/step - accuracy: 0.6412 - loss: 0.9733 - val_accuracy: 0.6073 - val_loss: 1.1138 - learning_rate: 5.0000e-04
# Epoch 72/10000
#
# Epoch 72: val_accuracy improved from 0.61132 to 0.61780, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 72: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.6512 - loss: 0.9409 - val_accuracy: 0.6178 - val_loss: 1.0874 - learning_rate: 2.5000e-04
# Epoch 73/10000
#
# Epoch 73: val_accuracy did not improve from 0.61780
# 330/330 - 21s - 64ms/step - accuracy: 0.6549 - loss: 0.9257 - val_accuracy: 0.6166 - val_loss: 1.0895 - learning_rate: 2.5000e-04
# Epoch 74/10000
#
# Epoch 74: val_accuracy did not improve from 0.61780
# 330/330 - 21s - 64ms/step - accuracy: 0.6546 - loss: 0.9238 - val_accuracy: 0.6127 - val_loss: 1.1220 - learning_rate: 2.5000e-04
# Epoch 75/10000
#
# Epoch 75: val_accuracy did not improve from 0.61780
# 330/330 - 21s - 64ms/step - accuracy: 0.6571 - loss: 0.9176 - val_accuracy: 0.6166 - val_loss: 1.0935 - learning_rate: 2.5000e-04
# Epoch 76/10000
#
# Epoch 76: val_accuracy did not improve from 0.61780
# 330/330 - 21s - 64ms/step - accuracy: 0.6593 - loss: 0.9093 - val_accuracy: 0.6139 - val_loss: 1.1185 - learning_rate: 2.5000e-04
# Epoch 77/10000
#
# Epoch 77: val_accuracy improved from 0.61780 to 0.61811, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 77: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.6593 - loss: 0.9066 - val_accuracy: 0.6181 - val_loss: 1.1015 - learning_rate: 2.5000e-04
# Epoch 78/10000
#
# Epoch 78: val_accuracy did not improve from 0.61811
# 330/330 - 21s - 64ms/step - accuracy: 0.6601 - loss: 0.9047 - val_accuracy: 0.6161 - val_loss: 1.1109 - learning_rate: 2.5000e-04
# Epoch 79/10000
#
# Epoch 79: val_accuracy did not improve from 0.61811
# 330/330 - 21s - 64ms/step - accuracy: 0.6594 - loss: 0.9077 - val_accuracy: 0.6110 - val_loss: 1.1563 - learning_rate: 2.5000e-04
# Epoch 80/10000
#
# Epoch 80: val_accuracy did not improve from 0.61811
# 330/330 - 21s - 64ms/step - accuracy: 0.6605 - loss: 0.9015 - val_accuracy: 0.6170 - val_loss: 1.1171 - learning_rate: 2.5000e-04
# Epoch 81/10000
#
# Epoch 81: val_accuracy improved from 0.61811 to 0.61930, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 81: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.6637 - loss: 0.8976 - val_accuracy: 0.6193 - val_loss: 1.1050 - learning_rate: 2.5000e-04
# Epoch 82/10000
#
# Epoch 82: val_accuracy did not improve from 0.61930
# 330/330 - 21s - 64ms/step - accuracy: 0.6619 - loss: 0.8968 - val_accuracy: 0.6177 - val_loss: 1.1138 - learning_rate: 2.5000e-04
# Epoch 83/10000
#
# Epoch 83: val_accuracy did not improve from 0.61930
# 330/330 - 21s - 64ms/step - accuracy: 0.6644 - loss: 0.8916 - val_accuracy: 0.6190 - val_loss: 1.1138 - learning_rate: 2.5000e-04
# Epoch 84/10000
#
# Epoch 84: val_accuracy did not improve from 0.61930
# 330/330 - 21s - 65ms/step - accuracy: 0.6660 - loss: 0.8877 - val_accuracy: 0.6155 - val_loss: 1.1446 - learning_rate: 2.5000e-04
# Epoch 85/10000
#
# Epoch 85: val_accuracy did not improve from 0.61930
# 330/330 - 21s - 64ms/step - accuracy: 0.6670 - loss: 0.8868 - val_accuracy: 0.6188 - val_loss: 1.1253 - learning_rate: 2.5000e-04
# Epoch 86/10000
#
# Epoch 86: val_accuracy improved from 0.61930 to 0.61989, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 86: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.6682 - loss: 0.8825 - val_accuracy: 0.6199 - val_loss: 1.1252 - learning_rate: 2.5000e-04
# Epoch 87/10000
#
# Epoch 87: val_accuracy did not improve from 0.61989
# 330/330 - 21s - 64ms/step - accuracy: 0.6670 - loss: 0.8862 - val_accuracy: 0.6167 - val_loss: 1.1452 - learning_rate: 2.5000e-04
# Epoch 88/10000
#
# Epoch 88: val_accuracy did not improve from 0.61989
# 330/330 - 21s - 65ms/step - accuracy: 0.6687 - loss: 0.8830 - val_accuracy: 0.6197 - val_loss: 1.1262 - learning_rate: 2.5000e-04
# Epoch 89/10000
#
# Epoch 89: val_accuracy did not improve from 0.61989
# 330/330 - 21s - 64ms/step - accuracy: 0.6712 - loss: 0.8747 - val_accuracy: 0.6192 - val_loss: 1.1313 - learning_rate: 2.5000e-04
# Epoch 90/10000
#
# Epoch 90: val_accuracy did not improve from 0.61989
# 330/330 - 21s - 64ms/step - accuracy: 0.6707 - loss: 0.8731 - val_accuracy: 0.6159 - val_loss: 1.1342 - learning_rate: 2.5000e-04
# Epoch 91/10000
#
# Epoch 91: val_accuracy improved from 0.61989 to 0.62002, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 91: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.6710 - loss: 0.8762 - val_accuracy: 0.6200 - val_loss: 1.1327 - learning_rate: 2.5000e-04
# Epoch 92/10000
#
# Epoch 92: val_accuracy did not improve from 0.62002
# 330/330 - 21s - 64ms/step - accuracy: 0.6687 - loss: 0.8788 - val_accuracy: 0.6189 - val_loss: 1.1312 - learning_rate: 2.5000e-04
# Epoch 93/10000
#
# Epoch 93: val_accuracy improved from 0.62002 to 0.62064, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 93: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.6714 - loss: 0.8721 - val_accuracy: 0.6206 - val_loss: 1.1342 - learning_rate: 2.5000e-04
# Epoch 94/10000
#
# Epoch 94: val_accuracy did not improve from 0.62064
# 330/330 - 21s - 64ms/step - accuracy: 0.6729 - loss: 0.8685 - val_accuracy: 0.6198 - val_loss: 1.1639 - learning_rate: 2.5000e-04
# Epoch 95/10000
#
# Epoch 95: val_accuracy did not improve from 0.62064
# 330/330 - 21s - 64ms/step - accuracy: 0.6723 - loss: 0.8724 - val_accuracy: 0.6162 - val_loss: 1.1798 - learning_rate: 2.5000e-04
# Epoch 96/10000
#
# Epoch 96: val_accuracy did not improve from 0.62064
# 330/330 - 21s - 64ms/step - accuracy: 0.6743 - loss: 0.8710 - val_accuracy: 0.6182 - val_loss: 1.1901 - learning_rate: 2.5000e-04
# Epoch 97/10000
#
# Epoch 97: val_accuracy did not improve from 0.62064
# 330/330 - 21s - 64ms/step - accuracy: 0.6756 - loss: 0.8648 - val_accuracy: 0.6181 - val_loss: 1.1713 - learning_rate: 2.5000e-04
# Epoch 98/10000
#
# Epoch 98: val_accuracy did not improve from 0.62064
# 330/330 - 21s - 64ms/step - accuracy: 0.6748 - loss: 0.8646 - val_accuracy: 0.6134 - val_loss: 1.2016 - learning_rate: 2.5000e-04
# Epoch 99/10000
#
# Epoch 99: val_accuracy did not improve from 0.62064
# 330/330 - 21s - 64ms/step - accuracy: 0.6752 - loss: 0.8634 - val_accuracy: 0.6148 - val_loss: 1.1749 - learning_rate: 2.5000e-04
# Epoch 100/10000
#
# Epoch 100: val_accuracy did not improve from 0.62064
# 330/330 - 21s - 64ms/step - accuracy: 0.6752 - loss: 0.8677 - val_accuracy: 0.6151 - val_loss: 1.1948 - learning_rate: 2.5000e-04
# Epoch 101/10000
#
# Epoch 101: val_accuracy did not improve from 0.62064
#
# Epoch 101: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 330/330 - 21s - 64ms/step - accuracy: 0.6768 - loss: 0.8636 - val_accuracy: 0.6200 - val_loss: 1.1605 - learning_rate: 2.5000e-04
# Epoch 102/10000
#
# Epoch 102: val_accuracy improved from 0.62064 to 0.62193, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 102: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.6833 - loss: 0.8442 - val_accuracy: 0.6219 - val_loss: 1.1370 - learning_rate: 1.2500e-04
# Epoch 103/10000
#
# Epoch 103: val_accuracy did not improve from 0.62193
# 330/330 - 21s - 64ms/step - accuracy: 0.6835 - loss: 0.8396 - val_accuracy: 0.6209 - val_loss: 1.1314 - learning_rate: 1.2500e-04
# Epoch 104/10000
#
# Epoch 104: val_accuracy improved from 0.62193 to 0.62493, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 104: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.6870 - loss: 0.8310 - val_accuracy: 0.6249 - val_loss: 1.1255 - learning_rate: 1.2500e-04
# Epoch 105/10000
#
# Epoch 105: val_accuracy improved from 0.62493 to 0.62634, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 105: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.6886 - loss: 0.8273 - val_accuracy: 0.6263 - val_loss: 1.1390 - learning_rate: 1.2500e-04
# Epoch 106/10000
#
# Epoch 106: val_accuracy improved from 0.62634 to 0.62666, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 106: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.6872 - loss: 0.8269 - val_accuracy: 0.6267 - val_loss: 1.1527 - learning_rate: 1.2500e-04
# Epoch 107/10000
#
# Epoch 107: val_accuracy did not improve from 0.62666
# 330/330 - 21s - 64ms/step - accuracy: 0.6905 - loss: 0.8221 - val_accuracy: 0.6225 - val_loss: 1.1510 - learning_rate: 1.2500e-04
# Epoch 108/10000
#
# Epoch 108: val_accuracy did not improve from 0.62666
# 330/330 - 21s - 64ms/step - accuracy: 0.6913 - loss: 0.8156 - val_accuracy: 0.6170 - val_loss: 1.1870 - learning_rate: 1.2500e-04
# Epoch 109/10000
#
# Epoch 109: val_accuracy did not improve from 0.62666
# 330/330 - 21s - 65ms/step - accuracy: 0.6908 - loss: 0.8166 - val_accuracy: 0.6241 - val_loss: 1.1564 - learning_rate: 1.2500e-04
# Epoch 110/10000
#
# Epoch 110: val_accuracy did not improve from 0.62666
# 330/330 - 21s - 65ms/step - accuracy: 0.6922 - loss: 0.8141 - val_accuracy: 0.6247 - val_loss: 1.1679 - learning_rate: 1.2500e-04
# Epoch 111/10000
#
# Epoch 111: val_accuracy did not improve from 0.62666
# 330/330 - 21s - 65ms/step - accuracy: 0.6930 - loss: 0.8125 - val_accuracy: 0.6259 - val_loss: 1.1673 - learning_rate: 1.2500e-04
# Epoch 112/10000
#
# Epoch 112: val_accuracy did not improve from 0.62666
# 330/330 - 21s - 65ms/step - accuracy: 0.6937 - loss: 0.8055 - val_accuracy: 0.6256 - val_loss: 1.1578 - learning_rate: 1.2500e-04
# Epoch 113/10000
#
# Epoch 113: val_accuracy did not improve from 0.62666
# 330/330 - 21s - 64ms/step - accuracy: 0.6939 - loss: 0.8073 - val_accuracy: 0.6210 - val_loss: 1.1844 - learning_rate: 1.2500e-04
# Epoch 114/10000
#
# Epoch 114: val_accuracy did not improve from 0.62666
#
# Epoch 114: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 330/330 - 21s - 65ms/step - accuracy: 0.6957 - loss: 0.8036 - val_accuracy: 0.6249 - val_loss: 1.1890 - learning_rate: 1.2500e-04
# Epoch 115/10000
#
# Epoch 115: val_accuracy improved from 0.62666 to 0.62759, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 115: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.6997 - loss: 0.7938 - val_accuracy: 0.6276 - val_loss: 1.1793 - learning_rate: 6.2500e-05
# Epoch 116/10000
#
# Epoch 116: val_accuracy did not improve from 0.62759
# 330/330 - 21s - 65ms/step - accuracy: 0.6998 - loss: 0.7881 - val_accuracy: 0.6258 - val_loss: 1.1895 - learning_rate: 6.2500e-05
# Epoch 117/10000
#
# Epoch 117: val_accuracy did not improve from 0.62759
# 330/330 - 21s - 64ms/step - accuracy: 0.7025 - loss: 0.7823 - val_accuracy: 0.6264 - val_loss: 1.1966 - learning_rate: 6.2500e-05
# Epoch 118/10000
#
# Epoch 118: val_accuracy did not improve from 0.62759
# 330/330 - 21s - 65ms/step - accuracy: 0.7010 - loss: 0.7813 - val_accuracy: 0.6242 - val_loss: 1.2027 - learning_rate: 6.2500e-05
# Epoch 119/10000
#
# Epoch 119: val_accuracy did not improve from 0.62759
# 330/330 - 21s - 64ms/step - accuracy: 0.7030 - loss: 0.7806 - val_accuracy: 0.6248 - val_loss: 1.1967 - learning_rate: 6.2500e-05
# Epoch 120/10000
#
# Epoch 120: val_accuracy did not improve from 0.62759
# 330/330 - 21s - 65ms/step - accuracy: 0.7047 - loss: 0.7735 - val_accuracy: 0.6238 - val_loss: 1.2016 - learning_rate: 6.2500e-05
# Epoch 121/10000
#
# Epoch 121: val_accuracy did not improve from 0.62759
# 330/330 - 21s - 64ms/step - accuracy: 0.7049 - loss: 0.7753 - val_accuracy: 0.6266 - val_loss: 1.2025 - learning_rate: 6.2500e-05
# Epoch 122/10000
#
# Epoch 122: val_accuracy did not improve from 0.62759
# 330/330 - 21s - 65ms/step - accuracy: 0.7057 - loss: 0.7719 - val_accuracy: 0.6217 - val_loss: 1.2086 - learning_rate: 6.2500e-05
# Epoch 123/10000
#
# Epoch 123: val_accuracy did not improve from 0.62759
#
# Epoch 123: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 330/330 - 21s - 65ms/step - accuracy: 0.7062 - loss: 0.7722 - val_accuracy: 0.6253 - val_loss: 1.2014 - learning_rate: 6.2500e-05
# Epoch 124/10000
#
# Epoch 124: val_accuracy did not improve from 0.62759
# 330/330 - 21s - 65ms/step - accuracy: 0.7077 - loss: 0.7655 - val_accuracy: 0.6266 - val_loss: 1.1862 - learning_rate: 3.1250e-05
# Epoch 125/10000
#
# Epoch 125: val_accuracy improved from 0.62759 to 0.62920, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 125: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 22s - 65ms/step - accuracy: 0.7083 - loss: 0.7613 - val_accuracy: 0.6292 - val_loss: 1.1885 - learning_rate: 3.1250e-05
# Epoch 126/10000
#
# Epoch 126: val_accuracy did not improve from 0.62920
# 330/330 - 21s - 65ms/step - accuracy: 0.7108 - loss: 0.7564 - val_accuracy: 0.6283 - val_loss: 1.1909 - learning_rate: 3.1250e-05
# Epoch 127/10000
#
# Epoch 127: val_accuracy did not improve from 0.62920
# 330/330 - 21s - 65ms/step - accuracy: 0.7111 - loss: 0.7570 - val_accuracy: 0.6288 - val_loss: 1.1959 - learning_rate: 3.1250e-05
# Epoch 128/10000
#
# Epoch 128: val_accuracy did not improve from 0.62920
# 330/330 - 21s - 65ms/step - accuracy: 0.7112 - loss: 0.7530 - val_accuracy: 0.6286 - val_loss: 1.1988 - learning_rate: 3.1250e-05
# Epoch 129/10000
#
# Epoch 129: val_accuracy did not improve from 0.62920
# 330/330 - 21s - 65ms/step - accuracy: 0.7119 - loss: 0.7515 - val_accuracy: 0.6270 - val_loss: 1.2086 - learning_rate: 3.1250e-05
# Epoch 130/10000
#
# Epoch 130: val_accuracy did not improve from 0.62920
# 330/330 - 21s - 65ms/step - accuracy: 0.7121 - loss: 0.7504 - val_accuracy: 0.6268 - val_loss: 1.2095 - learning_rate: 3.1250e-05
# Epoch 131/10000
#
# Epoch 131: val_accuracy did not improve from 0.62920
# 330/330 - 21s - 65ms/step - accuracy: 0.7124 - loss: 0.7490 - val_accuracy: 0.6267 - val_loss: 1.2149 - learning_rate: 3.1250e-05
# Epoch 132/10000
#
# Epoch 132: val_accuracy did not improve from 0.62920
# 330/330 - 21s - 64ms/step - accuracy: 0.7140 - loss: 0.7454 - val_accuracy: 0.6278 - val_loss: 1.2148 - learning_rate: 3.1250e-05
# Epoch 133/10000
#
# Epoch 133: val_accuracy did not improve from 0.62920
#
# Epoch 133: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 330/330 - 21s - 64ms/step - accuracy: 0.7142 - loss: 0.7463 - val_accuracy: 0.6286 - val_loss: 1.2154 - learning_rate: 3.1250e-05
# Epoch 134/10000
#
# Epoch 134: val_accuracy did not improve from 0.62920
# 330/330 - 21s - 65ms/step - accuracy: 0.7148 - loss: 0.7460 - val_accuracy: 0.6242 - val_loss: 1.2413 - learning_rate: 1.5625e-05
# Epoch 135/10000
#
# Epoch 135: val_accuracy did not improve from 0.62920
# 330/330 - 21s - 65ms/step - accuracy: 0.7155 - loss: 0.7423 - val_accuracy: 0.6220 - val_loss: 1.2579 - learning_rate: 1.5625e-05
# Epoch 136/10000
#
# Epoch 136: val_accuracy did not improve from 0.62920
# 330/330 - 21s - 65ms/step - accuracy: 0.7157 - loss: 0.7411 - val_accuracy: 0.6223 - val_loss: 1.2580 - learning_rate: 1.5625e-05
# Epoch 137/10000
#
# Epoch 137: val_accuracy did not improve from 0.62920
# 330/330 - 21s - 65ms/step - accuracy: 0.7157 - loss: 0.7403 - val_accuracy: 0.6229 - val_loss: 1.2641 - learning_rate: 1.5625e-05
# Epoch 138/10000
#
# Epoch 138: val_accuracy did not improve from 0.62920
# 330/330 - 21s - 65ms/step - accuracy: 0.7168 - loss: 0.7395 - val_accuracy: 0.6245 - val_loss: 1.2565 - learning_rate: 1.5625e-05
# Epoch 139/10000
#
# Epoch 139: val_accuracy did not improve from 0.62920
# 330/330 - 21s - 65ms/step - accuracy: 0.7175 - loss: 0.7372 - val_accuracy: 0.6246 - val_loss: 1.2618 - learning_rate: 1.5625e-05
# Epoch 140/10000
#
# Epoch 140: val_accuracy did not improve from 0.62920
# 330/330 - 21s - 65ms/step - accuracy: 0.7177 - loss: 0.7356 - val_accuracy: 0.6219 - val_loss: 1.2767 - learning_rate: 1.5625e-05
# Epoch 141/10000
#
# Epoch 141: val_accuracy did not improve from 0.62920
#
# Epoch 141: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 330/330 - 21s - 65ms/step - accuracy: 0.7171 - loss: 0.7357 - val_accuracy: 0.6243 - val_loss: 1.2630 - learning_rate: 1.5625e-05
# Epoch 142/10000
#
# Epoch 142: val_accuracy improved from 0.62920 to 0.62975, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 142: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.7174 - loss: 0.7343 - val_accuracy: 0.6298 - val_loss: 1.2561 - learning_rate: 7.8125e-06
# Epoch 143/10000
#
# Epoch 143: val_accuracy did not improve from 0.62975
# 330/330 - 21s - 65ms/step - accuracy: 0.7178 - loss: 0.7320 - val_accuracy: 0.6292 - val_loss: 1.2595 - learning_rate: 7.8125e-06
# Epoch 144/10000
#
# Epoch 144: val_accuracy did not improve from 0.62975
# 330/330 - 21s - 65ms/step - accuracy: 0.7180 - loss: 0.7310 - val_accuracy: 0.6283 - val_loss: 1.2606 - learning_rate: 7.8125e-06
# Epoch 145/10000
#
# Epoch 145: val_accuracy did not improve from 0.62975
# 330/330 - 21s - 65ms/step - accuracy: 0.7192 - loss: 0.7304 - val_accuracy: 0.6283 - val_loss: 1.2632 - learning_rate: 7.8125e-06
# Epoch 146/10000
#
# Epoch 146: val_accuracy did not improve from 0.62975
# 330/330 - 21s - 65ms/step - accuracy: 0.7187 - loss: 0.7299 - val_accuracy: 0.6287 - val_loss: 1.2644 - learning_rate: 7.8125e-06
# Epoch 147/10000
#
# Epoch 147: val_accuracy did not improve from 0.62975
# 330/330 - 21s - 65ms/step - accuracy: 0.7201 - loss: 0.7282 - val_accuracy: 0.6283 - val_loss: 1.2672 - learning_rate: 7.8125e-06
# Epoch 148/10000
#
# Epoch 148: val_accuracy did not improve from 0.62975
# 330/330 - 21s - 65ms/step - accuracy: 0.7201 - loss: 0.7280 - val_accuracy: 0.6281 - val_loss: 1.2713 - learning_rate: 7.8125e-06
# Epoch 149/10000
#
# Epoch 149: val_accuracy did not improve from 0.62975
# 330/330 - 21s - 65ms/step - accuracy: 0.7196 - loss: 0.7274 - val_accuracy: 0.6290 - val_loss: 1.2694 - learning_rate: 7.8125e-06
# Epoch 150/10000
#
# Epoch 150: val_accuracy did not improve from 0.62975
#
# Epoch 150: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 330/330 - 21s - 64ms/step - accuracy: 0.7193 - loss: 0.7265 - val_accuracy: 0.6288 - val_loss: 1.2705 - learning_rate: 7.8125e-06
# Epoch 151/10000
#
# Epoch 151: val_accuracy improved from 0.62975 to 0.63014, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 151: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 22s - 65ms/step - accuracy: 0.7207 - loss: 0.7265 - val_accuracy: 0.6301 - val_loss: 1.2658 - learning_rate: 3.9063e-06
# Epoch 152/10000
#
# Epoch 152: val_accuracy did not improve from 0.63014
# 330/330 - 21s - 65ms/step - accuracy: 0.7194 - loss: 0.7253 - val_accuracy: 0.6299 - val_loss: 1.2656 - learning_rate: 3.9063e-06
# Epoch 153/10000
#
# Epoch 153: val_accuracy did not improve from 0.63014
# 330/330 - 21s - 65ms/step - accuracy: 0.7207 - loss: 0.7247 - val_accuracy: 0.6292 - val_loss: 1.2663 - learning_rate: 3.9063e-06
# Epoch 154/10000
#
# Epoch 154: val_accuracy did not improve from 0.63014
# 330/330 - 21s - 65ms/step - accuracy: 0.7204 - loss: 0.7245 - val_accuracy: 0.6299 - val_loss: 1.2674 - learning_rate: 3.9063e-06
# Epoch 155/10000
#
# Epoch 155: val_accuracy did not improve from 0.63014
# 330/330 - 21s - 65ms/step - accuracy: 0.7208 - loss: 0.7236 - val_accuracy: 0.6296 - val_loss: 1.2692 - learning_rate: 3.9063e-06
# Epoch 156/10000
#
# Epoch 156: val_accuracy did not improve from 0.63014
# 330/330 - 21s - 65ms/step - accuracy: 0.7203 - loss: 0.7238 - val_accuracy: 0.6292 - val_loss: 1.2697 - learning_rate: 3.9063e-06
# Epoch 157/10000
#
# Epoch 157: val_accuracy did not improve from 0.63014
# 330/330 - 21s - 65ms/step - accuracy: 0.7217 - loss: 0.7231 - val_accuracy: 0.6292 - val_loss: 1.2718 - learning_rate: 3.9063e-06
# Epoch 158/10000
#
# Epoch 158: val_accuracy did not improve from 0.63014
# 330/330 - 21s - 65ms/step - accuracy: 0.7212 - loss: 0.7225 - val_accuracy: 0.6296 - val_loss: 1.2711 - learning_rate: 3.9063e-06
# Epoch 159/10000
#
# Epoch 159: val_accuracy did not improve from 0.63014
#
# Epoch 159: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 330/330 - 21s - 64ms/step - accuracy: 0.7221 - loss: 0.7226 - val_accuracy: 0.6295 - val_loss: 1.2709 - learning_rate: 3.9063e-06
# Epoch 160/10000
#
# Epoch 160: val_accuracy improved from 0.63014 to 0.63041, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 160: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.7212 - loss: 0.7224 - val_accuracy: 0.6304 - val_loss: 1.2669 - learning_rate: 1.9531e-06
# Epoch 161/10000
#
# Epoch 161: val_accuracy improved from 0.63041 to 0.63061, saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
#
# Epoch 161: finished saving model to experiments/11class_baseline/checkpoints/best_model.weights.h5
# 330/330 - 21s - 64ms/step - accuracy: 0.7217 - loss: 0.7218 - val_accuracy: 0.6306 - val_loss: 1.2671 - learning_rate: 1.9531e-06
# Epoch 162/10000
#
# Epoch 162: val_accuracy did not improve from 0.63061
# 330/330 - 21s - 64ms/step - accuracy: 0.7225 - loss: 0.7214 - val_accuracy: 0.6304 - val_loss: 1.2677 - learning_rate: 1.9531e-06
# Epoch 163/10000
#
# Epoch 163: val_accuracy did not improve from 0.63061
# 330/330 - 21s - 65ms/step - accuracy: 0.7225 - loss: 0.7208 - val_accuracy: 0.6303 - val_loss: 1.2693 - learning_rate: 1.9531e-06
# Epoch 164/10000
#
# Epoch 164: val_accuracy did not improve from 0.63061
# 330/330 - 21s - 64ms/step - accuracy: 0.7211 - loss: 0.7211 - val_accuracy: 0.6305 - val_loss: 1.2689 - learning_rate: 1.9531e-06
# Epoch 165/10000
#
# Epoch 165: val_accuracy did not improve from 0.63061
# 330/330 - 21s - 64ms/step - accuracy: 0.7214 - loss: 0.7209 - val_accuracy: 0.6299 - val_loss: 1.2694 - learning_rate: 1.9531e-06
# Epoch 166/10000
#
# Epoch 166: val_accuracy did not improve from 0.63061
# 330/330 - 21s - 64ms/step - accuracy: 0.7223 - loss: 0.7199 - val_accuracy: 0.6304 - val_loss: 1.2703 - learning_rate: 1.9531e-06
# Epoch 167/10000
#
# Epoch 167: val_accuracy did not improve from 0.63061
# 330/330 - 21s - 64ms/step - accuracy: 0.7210 - loss: 0.7201 - val_accuracy: 0.6304 - val_loss: 1.2707 - learning_rate: 1.9531e-06
# Epoch 168/10000
#
# Epoch 168: val_accuracy did not improve from 0.63061
# 330/330 - 21s - 64ms/step - accuracy: 0.7217 - loss: 0.7213 - val_accuracy: 0.6300 - val_loss: 1.2714 - learning_rate: 1.9531e-06
# Epoch 169/10000
#
# Epoch 169: val_accuracy did not improve from 0.63061
#
# Epoch 169: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 330/330 - 21s - 64ms/step - accuracy: 0.7228 - loss: 0.7202 - val_accuracy: 0.6299 - val_loss: 1.2721 - learning_rate: 1.9531e-06
# Epoch 170/10000
#
# Epoch 170: val_accuracy did not improve from 0.63061
# ...
# Epoch 166/10000
#
# Epoch 166: val_accuracy did not improve from 0.67468
# 330/330 - 21s - 65ms/step - accuracy: 0.7662 - loss: 0.9119 - val_accuracy: 0.6734 - val_loss: 1.2865 - learning_rate: 3.1250e-05
# Epoch 167/10000
#
# Epoch 167: val_accuracy did not improve from 0.67468
# 330/330 - 21s - 65ms/step - accuracy: 0.7665 - loss: 0.9112 - val_accuracy: 0.6740 - val_loss: 1.2888 - learning_rate: 3.1250e-05
# Epoch 168/10000
#
# Epoch 168: val_accuracy did not improve from 0.67468
# 330/330 - 21s - 65ms/step - accuracy: 0.7663 - loss: 0.9116 - val_accuracy: 0.6732 - val_loss: 1.2812 - learning_rate: 3.1250e-05
# Epoch 169/10000
#
# Epoch 169: val_accuracy did not improve from 0.67468
# 330/330 - 21s - 65ms/step - accuracy: 0.7672 - loss: 0.9101 - val_accuracy: 0.6742 - val_loss: 1.2809 - learning_rate: 3.1250e-05
# Epoch 170/10000
#
# Epoch 170: val_accuracy did not improve from 0.67468
#
# Epoch 170: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 330/330 - 21s - 64ms/step - accuracy: 0.7681 - loss: 0.9105 - val_accuracy: 0.6743 - val_loss: 1.2838 - learning_rate: 3.1250e-05
# Epoch 171/10000
#
# Epoch 171: val_accuracy did not improve from 0.67468
# 330/330 - 21s - 64ms/step - accuracy: 0.7686 - loss: 0.9061 - val_accuracy: 0.6741 - val_loss: 1.2842 - learning_rate: 1.5625e-05
# Epoch 172/10000
#
# Epoch 172: val_accuracy did not improve from 0.67468
# 330/330 - 21s - 64ms/step - accuracy: 0.7706 - loss: 0.9040 - val_accuracy: 0.6743 - val_loss: 1.2850 - learning_rate: 1.5625e-05
# Epoch 173/10000
#
# Epoch 173: val_accuracy did not improve from 0.67468
# 330/330 - 21s - 65ms/step - accuracy: 0.7690 - loss: 0.9059 - val_accuracy: 0.6743 - val_loss: 1.2866 - learning_rate: 1.5625e-05
# Epoch 174/10000
#
# Epoch 174: val_accuracy did not improve from 0.67468
# 330/330 - 21s - 64ms/step - accuracy: 0.7692 - loss: 0.9044 - val_accuracy: 0.6739 - val_loss: 1.2859 - learning_rate: 1.5625e-05
# Epoch 175/10000
#
# Epoch 175: val_accuracy did not improve from 0.67468
# 330/330 - 21s - 64ms/step - accuracy: 0.7703 - loss: 0.9038 - val_accuracy: 0.6743 - val_loss: 1.2885 - learning_rate: 1.5625e-05
# Epoch 176/10000
#
# Epoch 176: val_accuracy improved from 0.67468 to 0.67498, saving model to experiments/11class_attention_strong/checkpoints/best_model.weights.h5
#
# Epoch 176: finished saving model to experiments/11class_attention_strong/checkpoints/best_model.weights.h5
# 330/330 - 21s - 65ms/step - accuracy: 0.7688 - loss: 0.9052 - val_accuracy: 0.6750 - val_loss: 1.2871 - learning_rate: 1.5625e-05
# Epoch 177/10000
#
# Epoch 177: val_accuracy did not improve from 0.67498
# 330/330 - 21s - 64ms/step - accuracy: 0.7699 - loss: 0.9050 - val_accuracy: 0.6737 - val_loss: 1.2934 - learning_rate: 1.5625e-05
# Epoch 178/10000
#
# Epoch 178: val_accuracy did not improve from 0.67498
# 330/330 - 21s - 64ms/step - accuracy: 0.7704 - loss: 0.9038 - val_accuracy: 0.6743 - val_loss: 1.2897 - learning_rate: 1.5625e-05
# Epoch 179/10000
#
# Epoch 179: val_accuracy did not improve from 0.67498
# 330/330 - 21s - 64ms/step - accuracy: 0.7708 - loss: 0.9037 - val_accuracy: 0.6746 - val_loss: 1.2881 - learning_rate: 1.5625e-05
# Epoch 180/10000
#
# Epoch 180: val_accuracy did not improve from 0.67498
# 330/330 - 21s - 65ms/step - accuracy: 0.7708 - loss: 0.9033 - val_accuracy: 0.6738 - val_loss: 1.2918 - learning_rate: 1.5625e-05
# Epoch 181/10000
#
# Epoch 181: val_accuracy did not improve from 0.67498
# 330/330 - 21s - 65ms/step - accuracy: 0.7710 - loss: 0.9030 - val_accuracy: 0.6743 - val_loss: 1.2925 - learning_rate: 1.5625e-05
# Epoch 182/10000
#
# Epoch 182: val_accuracy did not improve from 0.67498
# 330/330 - 21s - 65ms/step - accuracy: 0.7692 - loss: 0.9030 - val_accuracy: 0.6744 - val_loss: 1.2877 - learning_rate: 1.5625e-05
# Epoch 183/10000
#
# Epoch 183: val_accuracy did not improve from 0.67498
#
# Epoch 183: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 330/330 - 21s - 65ms/step - accuracy: 0.7710 - loss: 0.9035 - val_accuracy: 0.6744 - val_loss: 1.2892 - learning_rate: 1.5625e-05
# Epoch 184/10000
#
# Epoch 184: val_accuracy did not improve from 0.67498
# 330/330 - 21s - 65ms/step - accuracy: 0.7711 - loss: 0.9012 - val_accuracy: 0.6744 - val_loss: 1.2905 - learning_rate: 7.8125e-06
# Epoch 185/10000
#
# Epoch 185: val_accuracy did not improve from 0.67498
# 330/330 - 21s - 65ms/step - accuracy: 0.7714 - loss: 0.9002 - val_accuracy: 0.6741 - val_loss: 1.2931 - learning_rate: 7.8125e-06
# Epoch 186/10000
#
# Epoch 186: val_accuracy did not improve from 0.67498
# 330/330 - 21s - 65ms/step - accuracy: 0.7704 - loss: 0.9008 - val_accuracy: 0.6745 - val_loss: 1.2902 - learning_rate: 7.8125e-06
# Epoch 187/10000
#
# Epoch 187: val_accuracy did not improve from 0.67498
# 330/330 - 21s - 65ms/step - accuracy: 0.7708 - loss: 0.8999 - val_accuracy: 0.6748 - val_loss: 1.2890 - learning_rate: 7.8125e-06
# Epoch 188/10000
#
# Epoch 188: val_accuracy did not improve from 0.67498
# 330/330 - 21s - 65ms/step - accuracy: 0.7707 - loss: 0.9006 - val_accuracy: 0.6745 - val_loss: 1.2909 - learning_rate: 7.8125e-06
# Epoch 189/10000
#
# Epoch 189: val_accuracy improved from 0.67498 to 0.67505, saving model to experiments/11class_attention_strong/checkpoints/best_model.weights.h5
#
# Epoch 189: finished saving model to experiments/11class_attention_strong/checkpoints/best_model.weights.h5
# 330/330 - 22s - 66ms/step - accuracy: 0.7720 - loss: 0.8997 - val_accuracy: 0.6750 - val_loss: 1.2920 - learning_rate: 7.8125e-06
# Epoch 190/10000
#
# Epoch 190: val_accuracy improved from 0.67505 to 0.67548, saving model to experiments/11class_attention_strong/checkpoints/best_model.weights.h5
#
# Epoch 190: finished saving model to experiments/11class_attention_strong/checkpoints/best_model.weights.h5
# 330/330 - 22s - 65ms/step - accuracy: 0.7716 - loss: 0.9005 - val_accuracy: 0.6755 - val_loss: 1.2904 - learning_rate: 7.8125e-06
# Epoch 191/10000
#
# Epoch 191: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7717 - loss: 0.9003 - val_accuracy: 0.6747 - val_loss: 1.2880 - learning_rate: 7.8125e-06
# Epoch 192/10000
#
# Epoch 192: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7726 - loss: 0.8995 - val_accuracy: 0.6743 - val_loss: 1.2916 - learning_rate: 7.8125e-06
# Epoch 193/10000
#
# Epoch 193: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7722 - loss: 0.8990 - val_accuracy: 0.6747 - val_loss: 1.2905 - learning_rate: 7.8125e-06
# Epoch 194/10000
#
# Epoch 194: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7718 - loss: 0.8993 - val_accuracy: 0.6741 - val_loss: 1.2955 - learning_rate: 7.8125e-06
# Epoch 195/10000
#
# Epoch 195: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7718 - loss: 0.8978 - val_accuracy: 0.6747 - val_loss: 1.2919 - learning_rate: 7.8125e-06
# Epoch 196/10000
#
# Epoch 196: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7705 - loss: 0.8991 - val_accuracy: 0.6747 - val_loss: 1.2936 - learning_rate: 7.8125e-06
# Epoch 197/10000
#
# Epoch 197: val_accuracy did not improve from 0.67548
#
# Epoch 197: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 330/330 - 21s - 65ms/step - accuracy: 0.7718 - loss: 0.8990 - val_accuracy: 0.6748 - val_loss: 1.2930 - learning_rate: 7.8125e-06
# Epoch 198/10000
#
# Epoch 198: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7719 - loss: 0.8989 - val_accuracy: 0.6750 - val_loss: 1.2923 - learning_rate: 3.9063e-06
# Epoch 199/10000
#
# Epoch 199: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7730 - loss: 0.8973 - val_accuracy: 0.6745 - val_loss: 1.2932 - learning_rate: 3.9063e-06
# Epoch 200/10000
#
# Epoch 200: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7737 - loss: 0.8971 - val_accuracy: 0.6743 - val_loss: 1.2937 - learning_rate: 3.9063e-06
# Epoch 201/10000
#
# Epoch 201: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7729 - loss: 0.8972 - val_accuracy: 0.6754 - val_loss: 1.2932 - learning_rate: 3.9063e-06
# Epoch 202/10000
#
# Epoch 202: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7727 - loss: 0.8983 - val_accuracy: 0.6754 - val_loss: 1.2912 - learning_rate: 3.9063e-06
# Epoch 203/10000
#
# Epoch 203: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7720 - loss: 0.8974 - val_accuracy: 0.6747 - val_loss: 1.2938 - learning_rate: 3.9063e-06
# Epoch 204/10000
#
# Epoch 204: val_accuracy did not improve from 0.67548
#
# Epoch 204: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 330/330 - 21s - 65ms/step - accuracy: 0.7723 - loss: 0.8969 - val_accuracy: 0.6748 - val_loss: 1.2907 - learning_rate: 3.9063e-06
# Epoch 205/10000
#
# Epoch 205: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7743 - loss: 0.8959 - val_accuracy: 0.6749 - val_loss: 1.2932 - learning_rate: 1.9531e-06
# Epoch 206/10000
#
# Epoch 206: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7739 - loss: 0.8953 - val_accuracy: 0.6746 - val_loss: 1.2935 - learning_rate: 1.9531e-06
# Epoch 207/10000
#
# Epoch 207: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7734 - loss: 0.8964 - val_accuracy: 0.6746 - val_loss: 1.2919 - learning_rate: 1.9531e-06
# Epoch 208/10000
#
# Epoch 208: val_accuracy did not improve from 0.67548
# 330/330 - 21s - 65ms/step - accuracy: 0.7725 - loss: 0.8968 - val_accuracy: 0.6742 - val_loss: 1.2946 - learning_rate: 1.9531e-06
# Epoch 208: early stopping
# Restoring model weights from the end of the best epoch: 190.
# [mltools] History saved to experiments/11class_attention_strong/logs/
#
#   1/110 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.7225 - loss: 1.187
#   5/110 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7052 - loss: 1.242
#   9/110 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7004 - loss: 1.253
#  12/110 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6983 - loss: 1.258
#  15/110 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6967 - loss: 1.259
#  18/110 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6955 - loss: 1.260
#  21/110 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6946 - loss: 1.260
#  24/110 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6937 - loss: 1.260
#  28/110 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6923 - loss: 1.261
#  32/110 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6910 - loss: 1.261
#  36/110 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6901 - loss: 1.262
#  40/110 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6893 - loss: 1.263
#  44/110 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6886 - loss: 1.263
#  48/110 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6880 - loss: 1.264
#  52/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6873 - loss: 1.265
#  56/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6869 - loss: 1.265
#  60/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6864 - loss: 1.266
#  63/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6860 - loss: 1.266
#  66/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6856 - loss: 1.267
#  69/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6853 - loss: 1.267
#  72/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6850 - loss: 1.268
#  75/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6847 - loss: 1.268
#  78/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6844 - loss: 1.268
#  82/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6841 - loss: 1.269
#  86/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6837 - loss: 1.270
#  90/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6834 - loss: 1.270
#  94/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6831 - loss: 1.271
#  98/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6828 - loss: 1.271
# 101/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6826 - loss: 1.272
# 105/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6823 - loss: 1.272
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6820 - loss: 1.273
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6745 - loss: 1.2904
#
# [train] Test loss=1.2904  Test accuracy=0.6745
#
# [train] Running per-SNR evaluation ...
#
#   1/110 ━━━━━━━━━━━━━━━━━━━━ 3:14 2s/ste
#   5/110 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/ste
#   9/110 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/ste
#  13/110 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/ste
#  17/110 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/ste
#  21/110 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/ste
#  25/110 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/ste
#  29/110 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/ste
#  33/110 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/ste
#  37/110 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/ste
#  41/110 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/ste
#  45/110 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/ste
#  49/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
#  53/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
#  57/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
#  61/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
#  65/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
#  69/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
#  73/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
#  77/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
#  81/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
#  85/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
#  89/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
#  93/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
#  97/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 101/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 105/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/st
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 487ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/ste
# 4/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/ste
# 4/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/ste
# 4/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/ste
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/ste
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [mltools] Per-class accuracy figure saved to experiments/11class_attention_strong/figures/
#
# [train] Done. All outputs saved under experiments/11class_attention_strong/
# [train] Peak overall accuracy: 0.9350 at SNR=10 dB

# %%
# CELL 4: Load result CSVs and build comparison tables
models = {
    'Baseline LSTM': {
        'dir': BASELINE_DIR,
        'color': '#9467bd',
        'marker': 'x',
    },
    'Normal attention': {
        'dir': NORMAL_ATT_DIR,
        'color': '#1f77b4',
        'marker': 'o',
    },
    'Strong attention': {
        'dir': STRONG_ATT_DIR,
        'color': '#d62728',
        'marker': 's',
    },
}

rows = []

for name, cfg in models.items():
    score_csv = cfg['dir'] / 'results/test_score.csv'
    snr_csv = cfg['dir'] / 'results/acc_per_snr.csv'
    class_csv = cfg['dir'] / 'results/per_class_acc.csv'

    assert score_csv.exists(), f'Missing {score_csv}'
    assert snr_csv.exists(), f'Missing {snr_csv}'

    if not class_csv.exists():
        print(f'WARNING: Missing per-class CSV for {name}: {class_csv}')
        print('Continuing because per-class CSV is not required for SNR comparison.')

    score = pd.read_csv(score_csv)
    snr_df = pd.read_csv(snr_csv)

    acc_col = 'accuracy' if 'accuracy' in score.columns else score.columns[-1]

    test_acc = float(score[acc_col].iloc[0])
    mean_snr_acc = float(snr_df['accuracy'].mean())
    low_snr_acc = float(snr_df[snr_df['snr'] <= 0]['accuracy'].mean())
    high_snr_acc = float(snr_df[snr_df['snr'] >= 2]['accuracy'].mean())

    rows.append({
        'model': name,
        'test_accuracy': test_acc,
        'mean_snr_accuracy': mean_snr_acc,
        'low_snr_mean_acc_snr_le_0': low_snr_acc,
        'high_snr_mean_acc_snr_ge_2': high_snr_acc,
        'per_class_csv_found': class_csv.exists(),
        'results_dir': str(cfg['dir']),
    })

summary = pd.DataFrame(rows)
summary.to_csv(RES_DIR / '11class_model_summary.csv', index=False)

print('Summary')
display(summary)
print('Saved:', RES_DIR / '11class_model_summary.csv')

# Combined SNR table
snr_table = None

for name, cfg in models.items():
    snr_df = pd.read_csv(cfg['dir'] / 'results/acc_per_snr.csv')[['snr', 'accuracy']]
    snr_df = snr_df.rename(columns={'accuracy': name})
    snr_table = snr_df if snr_table is None else snr_table.merge(snr_df, on='snr', how='outer')

snr_table = snr_table.sort_values('snr')
snr_table['Strong minus normal'] = snr_table['Strong attention'] - snr_table['Normal attention']
snr_table['Strong minus LSTM'] = snr_table['Strong attention'] - snr_table['Baseline LSTM']

snr_table.to_csv(RES_DIR / '11class_acc_per_snr_comparison.csv', index=False)

display(snr_table)
print('Saved:', RES_DIR / '11class_acc_per_snr_comparison.csv')
# Out:
# WARNING: Missing per-class CSV for Baseline LSTM: experiments/11class_baseline/results/per_class_acc.csv
# Continuing because per-class CSV is not required for SNR comparison.
# WARNING: Missing per-class CSV for Normal attention: experiments/11class_attention/results/per_class_acc.csv
# Continuing because per-class CSV is not required for SNR comparison.
# WARNING: Missing per-class CSV for Strong attention: experiments/11class_attention_strong/results/per_class_acc.csv
# Continuing because per-class CSV is not required for SNR comparison.
# Summary
#               model  test_accuracy  mean_snr_accuracy  \
# 0     Baseline LSTM       0.626705           0.626705
# 1  Normal attention       0.640909           0.640909
# 2  Strong attention       0.674523           0.674523
#
#    low_snr_mean_acc_snr_le_0  high_snr_mean_acc_snr_ge_2  per_class_csv_found  \
# 0                   0.443884                    0.850152                False
# 1                   0.438884                    0.887828                False
# 2                   0.472066                    0.921970                False
#
#                             results_dir
# 0          experiments/11class_baseline
# 1         experiments/11class_attention
# 2  experiments/11class_attention_strong
# Saved: experiments/11class_attention_strong_comparison/results/11class_model_summary.csv
#     snr  Baseline LSTM  Normal attention  Strong attention  \
# 0   -20       0.245455          0.232273          0.293636
# 1   -18       0.300455          0.277727          0.325909
# 2   -16       0.323636          0.309545          0.342273
# 3   -14       0.326364          0.317273          0.375909
# 4   -12       0.344545          0.339091          0.363636
# 5   -10       0.354545          0.350000          0.377727
# 6    -8       0.388636          0.391818          0.417727
# 7    -6       0.464091          0.465455          0.483182
# 8    -4       0.587273          0.603182          0.626364
# 9    -2       0.732727          0.726364          0.746364
# 10    0       0.815000          0.815000          0.840000
# 11    2       0.841818          0.872727          0.895455
# 12    4       0.845909          0.870909          0.902273
# 13    6       0.850000          0.888182          0.920000
# 14    8       0.844091          0.891364          0.927727
# 15   10       0.853182          0.901818          0.935000
# 16   12       0.853182          0.894545          0.927273
# 17   14       0.861364          0.892727          0.934091
# 18   16       0.852727          0.890909          0.930909
# 19   18       0.849091          0.887273          0.925000
#
#     Strong minus normal  Strong minus LSTM
# 0              0.061364           0.048182
# 1              0.048182           0.025455
# 2              0.032727           0.018636
# 3              0.058636           0.049545
# 4              0.024545           0.019091
# 5              0.027727           0.023182
# 6              0.025909           0.029091
# 7              0.017727           0.019091
# 8              0.023182           0.039091
# 9              0.020000           0.013636
# 10             0.025000           0.025000
# 11             0.022727           0.053636
# 12             0.031364           0.056364
# 13             0.031818           0.070000
# 14             0.036364           0.083636
# 15             0.033182           0.081818
# 16             0.032727           0.074091
# 17             0.041364           0.072727
# 18             0.040000           0.078182
# 19             0.037727           0.075909
# Saved: experiments/11class_attention_strong_comparison/results/11class_acc_per_snr_comparison.csv

# %%
# CELL 5: Plot accuracy vs SNR and delta curves
snrs = snr_table['snr'].to_numpy()

plt.figure(figsize=(12.5, 6.4))
for name, cfg in models.items():
    ys = snr_table[name].to_numpy() * 100
    plt.plot(snrs, ys, marker=cfg['marker'], linewidth=2.5, color=cfg['color'], label=name)

plt.xlabel('SNR (dB)')
plt.ylabel('Test Accuracy (%)')
plt.title('11-class Comparison: Baseline LSTM vs Normal Attention vs Strong Attention')
plt.grid(True, alpha=0.3)
plt.xticks(snrs)
plt.legend()
plt.tight_layout()
acc_plot = FIG_DIR / '11class_lstm_normal_attention_strong_attention_acc_vs_snr.png'
plt.savefig(acc_plot, dpi=220, bbox_inches='tight')
plt.close()
display(Image(filename=str(acc_plot)))
print('Saved:', acc_plot)

plt.figure(figsize=(12, 5))
plt.plot(snrs, snr_table['Strong minus normal'].to_numpy() * 100,
         marker='s', linewidth=2.4, label='Strong attention - normal attention')
plt.plot(snrs, snr_table['Strong minus LSTM'].to_numpy() * 100,
         marker='x', linewidth=2.4, label='Strong attention - baseline LSTM')
plt.axhline(0, color='black', linewidth=1)
plt.xlabel('SNR (dB)')
plt.ylabel('Delta accuracy (percentage points)')
plt.title('11-class Strong Attention Delta vs Baselines')
plt.grid(True, alpha=0.3)
plt.xticks(snrs)
plt.legend()
plt.tight_layout()
delta_plot = FIG_DIR / '11class_strong_attention_delta_vs_baselines.png'
plt.savefig(delta_plot, dpi=220, bbox_inches='tight')
plt.close()
display(Image(filename=str(delta_plot)))
print('Saved:', delta_plot)
# Out:
# Saved: experiments/11class_attention_strong_comparison/figures/11class_lstm_normal_attention_strong_attention_acc_vs_snr.png
# Saved: experiments/11class_attention_strong_comparison/figures/11class_strong_attention_delta_vs_baselines.png

# %%
# CELL 6: Plot training histories and confusion matrices
for name, cfg in models.items():
    log_path = cfg['dir'] / 'logs/training_log.csv'
    if not log_path.exists():
        print('Missing training log:', log_path)
        continue
    log = pd.read_csv(log_path)
    epoch = log['epoch'] if 'epoch' in log.columns else np.arange(1, len(log) + 1)
    acc_col = next((c for c in log.columns if 'accuracy' in c and 'val' not in c), 'accuracy')
    val_acc_col = next((c for c in log.columns if 'val' in c and 'accuracy' in c), 'val_accuracy')

    fig, axes = plt.subplots(1, 2, figsize=(13, 5))
    fig.suptitle(f'{name} training history', fontweight='bold')
    axes[0].plot(epoch, log['loss'], label='train loss')
    axes[0].plot(epoch, log['val_loss'], label='val loss')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Loss')
    axes[0].grid(True, alpha=0.3)
    axes[0].legend()

    axes[1].plot(epoch, log[acc_col] * 100, label='train acc')
    axes[1].plot(epoch, log[val_acc_col] * 100, label='val acc')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Accuracy (%)')
    axes[1].grid(True, alpha=0.3)
    axes[1].legend()
    plt.tight_layout()

    safe = name.lower().replace(' ', '_')
    out = FIG_DIR / f'{safe}_training_history.png'
    plt.savefig(out, dpi=180, bbox_inches='tight')
    plt.close()
    display(Image(filename=str(out)))
    print('Saved:', out)

for name, cfg in models.items():
    cm_path = cfg['dir'] / 'figures/confusion_all_snrs.png'

    if cm_path.exists():
        print(f'\n{name} confusion matrix')
        display(Image(filename=str(cm_path)))
# Out:
# Saved: experiments/11class_attention_strong_comparison/figures/baseline_lstm_training_history.png
# Saved: experiments/11class_attention_strong_comparison/figures/normal_attention_training_history.png
# Saved: experiments/11class_attention_strong_comparison/figures/strong_attention_training_history.png
#
# Baseline LSTM confusion matrix
# Normal attention confusion matrix
# Strong attention confusion matrix

# %%
# CELL 7: Create repo-ready zip for strong attention comparison

stamp = datetime.now().strftime('%Y%m%d_%H%M')

zip_name = f'11class_strong_attention_comparison_repo_ready_{stamp}'

staging_dir = Path('/kaggle/working') / f'{zip_name}_staging'
zip_base = Path('/kaggle/working') / zip_name
zip_path = Path('/kaggle/working') / f'{zip_name}.zip'

# Clean old files
if staging_dir.exists():
    shutil.rmtree(staging_dir)

if zip_path.exists():
    zip_path.unlink()


folders_to_zip = [
    'experiments/11class_baseline',
    'experiments/11class_attention',
    'experiments/11class_attention_strong',
    'experiments/11class_attention_strong_comparison',
]


# Copy experiment folders
for rel_folder in folders_to_zip:
    src = WORK_DIR / rel_folder
    dst = staging_dir / rel_folder

    if src.exists():
        dst.parent.mkdir(parents=True, exist_ok=True)

        shutil.copytree(
            src,
            dst,
            dirs_exist_ok=True
        )

        print(f'Included: {rel_folder}')

    else:
        print(f'WARNING: Missing, not included: {rel_folder}')


# Create ZIP
created_zip = shutil.make_archive(
    str(zip_base),
    'zip',
    root_dir=str(staging_dir)
)


print('\nCreated repo-ready zip:')
print(created_zip)


print('\nExtract this at repo root. It will create/update:')

for rel_folder in folders_to_zip:
    print(f'  {rel_folder}/')


# Create simple results.zip
simple_zip = Path('/kaggle/working/results.zip')

if simple_zip.exists():
    simple_zip.unlink()

shutil.copy2(created_zip, simple_zip)


print('\nSimple download copy:', simple_zip)

print(
    'If direct link fails, use Kaggle right sidebar: '
    'Output -> /kaggle/working -> results.zip'
)


# Kaggle download links
display(FileLink(str(simple_zip)))

display(
    HTML(
        f'<a href="files/{simple_zip.name}" '
        f'target="_blank" download>'
        f'Download results.zip'
        f'</a>'
    )
)
# Out:
# Included: experiments/11class_baseline
# Included: experiments/11class_attention
# Included: experiments/11class_attention_strong
# Included: experiments/11class_attention_strong_comparison
#
# Created repo-ready zip:
# /kaggle/working/11class_strong_attention_comparison_repo_ready_20260714_1809.zip
#
# Extract this at repo root. It will create/update:
#   experiments/11class_baseline/
#   experiments/11class_attention/
#   experiments/11class_attention_strong/
#   experiments/11class_attention_strong_comparison/
#
# Simple download copy: /kaggle/working/results.zip
# If direct link fails, use Kaggle right sidebar: Output -> /kaggle/working -> results.zip
# /kaggle/working/results.zip
# <a href="files/results.zip" target="_blank" download>Download results.zip</a>
